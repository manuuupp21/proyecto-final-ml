# %%
#Chiildren da problemas para mostrarse por NaNs
#Mostrar valores distintos de la columna children 
print(df_preprocessed['children'].value_counts(dropna=False))
#Cambiar NaNs por 0
df_preprocessed['children'] = df_preprocessed['children'].fillna(0)
